# %%
import graphlab

# %%
data=graphlab.SFrame('people_wiki.gl/')
# Out:
# This non-commercial license of GraphLab Create for academic use is assigned to shuoyan001@e.ntu.edu.sg and will expire on June 10, 2019.
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.1 started. Logging: C:\Users\SHUOYA~1\AppData\Local\Temp\graphlab_server_1528864667.log.0

# %%
data.head()
# Out:
# Columns:
# 	URI	str
# 	name	str
# 	text	str
#
# Rows: 10
#
# Data:
# +-------------------------------+---------------------+
# |              URI              |         name        |
# +-------------------------------+---------------------+
# | <http://dbpedia.org/resour... |    Digby Morrell    |
# | <http://dbpedia.org/resour... |    Alfred J. Lewy   |
# | <http://dbpedia.org/resour... |    Harpdog Brown    |
# | <http://dbpedia.org/resour... | Franz Rottensteiner |
# | <http://dbpedia.org/resour... |        G-Enka       |
# | <http://dbpedia.org/resour... |    Sam Henderson    |
# | <http://dbpedia.org/resour... |    Aaron LaCrate    |
# | <http://dbpedia.org/resour... |   Trevor Ferguson   |
# | <http://dbpedia.org/resour... |     Grant Nelson    |
# | <http://dbpedia.org/resour... |     Cathy Caruth    |
# +-------------------------------+---------------------+
# +-------------------------------+
# |              text             |
# +-------------------------------+
# ...

# %%
 obama=data[data['name']=='Barack Obama']

# %%
obama
# Out:
# Columns:
# 	URI	str
# 	name	str
# 	text	str
#
# Rows: Unknown
#
# Data:
# +-------------------------------+--------------+-------------------------------+
# |              URI              |     name     |              text             |
# +-------------------------------+--------------+-------------------------------+
# | <http://dbpedia.org/resour... | Barack Obama | barack hussein obama ii br... |
# +-------------------------------+--------------+-------------------------------+
# [? rows x 3 columns]
# Note: Only the head of the SFrame is printed. This SFrame is lazily evaluated.
# You can use sf.materialize() to force materialization.

# %%
obama['word_count']=graphlab.text_analytics.count_words(obama['text'])

# %%
obama
# Out:
# Columns:
# 	URI	str
# 	name	str
# 	text	str
# 	word_count	dict
#
# Rows: 1
#
# Data:
# +-------------------------------+--------------+-------------------------------+
# |              URI              |     name     |              text             |
# +-------------------------------+--------------+-------------------------------+
# | <http://dbpedia.org/resour... | Barack Obama | barack hussein obama ii br... |
# +-------------------------------+--------------+-------------------------------+
# +-------------------------------+
# |           word_count          |
# +-------------------------------+
# | {'operations': 1L, 'repres... |
# +-------------------------------+
# [1 rows x 4 columns]

# %%
 obama['word_count'].sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-f5974a519645> in <module>()
# ----> 1 obama['word_count'].sort()
#
# C:\Users\shuoyan001\Anaconda2\envs\gl-env\lib\site-packages\graphlab\data_structures\sarray.pyc in sort(self, ascending)
#    3291
#    3292         if self.dtype() not in (int, float, str, datetime.datetime):
# -> 3293             raise TypeError("Only sarray with type (int, float, str, datetime.datetime) can be sorted")
#    3294         sf = _SFrame()
#    3295         sf['a'] = self
#
# TypeError: Only sarray with type (int, float, str, datetime.datetime) can be sorted

# %%
obama_word_table=obama[['word_count']].stack('word_count',new_column_name=['word','count'])

# %%
obama_word_table.sort('count',ascending=False)
# Out:
# Columns:
# 	word	str
# 	count	int
#
# Rows: 273
#
# Data:
# +-------+-------+
# |  word | count |
# +-------+-------+
# |  the  |   40  |
# |   in  |   30  |
# |  and  |   21  |
# |   of  |   18  |
# |   to  |   14  |
# |  his  |   11  |
# | obama |   9   |
# |  act  |   8   |
# |   a   |   7   |
# |   he  |   7   |
# +-------+-------+
# [273 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
data['word_count']=graphlab.text_analytics.count_words(data['text'])

# %%
data['tfidf']=graphlab.text_analytics.tf_idf(data['word_count'])

# %%
obama=data[data['name']=='Barack Obama']

# %%
obama[['tfidf']].stack('tfidf',new_column_name=['word','tfidf']).sort('tfidf',ascending=False)
obama[['tfidf']]
# Out:
# Columns:
# 	tfidf	dict
#
# Rows: 1
#
# Data:
# +-------------------------------+
# |             tfidf             |
# +-------------------------------+
# | {'operations': 3.811771079... |
# +-------------------------------+
# [1 rows x 1 columns]

# %%
clinton=data[data['name']=='Bill Clinton']

# %%
beck=data[data['name']=='David Beckham']

# %%
graphlab.distances.cosine(obama['tfidf'][0],beck['tfidf'][0])
# Out:
# 0.9791305844747478

# %%
knn_model=graphlab.nearest_neighbors.create(data,features=['tfidf'],label='name')
# Out:
# Starting brute force nearest neighbors model training.

# %%
knn_model.query(obama)
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.00169288  | 2.507ms      |
# | Done         |         | 100         | 253.519ms    |
# +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+-----------------+----------------+------+
# | query_label | reference_label |    distance    | rank |
# +-------------+-----------------+----------------+------+
# |      0      |   Barack Obama  |      0.0       |  1   |
# |      0      |    Joe Biden    | 0.794117647059 |  2   |
# |      0      |  Joe Lieberman  | 0.794685990338 |  3   |
# |      0      |   Kelly Ayotte  | 0.811989100817 |  4   |
# |      0      |   Bill Clinton  | 0.813852813853 |  5   |
# ...

# %%
e_table=data[data['name']=='Elton John'][['word_count']].stack('word_count',new_column_name=['word','count']).sort('count',ascending=False)

# %%
e_itf=data[data['name']=='Elton John'][['tfidf']].stack('tfidf',new_column_name=['word','tfidf']).sort('tfidf',ascending=False)

# %%
e_itf
# Out:
# Columns:
# 	word	str
# 	tfidf	float
#
# Rows: 255
#
# Data:
# +---------------+---------------+
# |      word     |     tfidf     |
# +---------------+---------------+
# |    furnish    |  18.38947184  |
# |     elton     |  17.48232027  |
# |   billboard   | 17.3036809575 |
# |      john     | 13.9393127924 |
# |  songwriters  |  11.250406447 |
# |  overallelton | 10.9864953892 |
# | tonightcandle | 10.9864953892 |
# |    19702000   | 10.2933482087 |
# |   fivedecade  | 10.2933482087 |
# |      aids     |  10.262846934 |
# +---------------+---------------+
# [255 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
e_table
# Out:
# Columns:
# 	word	str
# 	count	int
#
# Rows: 255
#
# Data:
# +-------+-------+
# |  word | count |
# +-------+-------+
# |  the  |   27  |
# |   in  |   18  |
# |  and  |   15  |
# |   of  |   13  |
# |   a   |   10  |
# |  has  |   9   |
# |   he  |   7   |
# |  john |   7   |
# |   on  |   6   |
# | since |   5   |
# +-------+-------+
# [255 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
a=graphlab.distances.cosine(data[data['name']=='Elton John']['tfidf'][0],data[data['name']=='Victoria Beckham']['tfidf'][0])
b=graphlab.distances.cosine(data[data['name']=='Elton John']['tfidf'][0],data[data['name']=='Paul McCartney']['tfidf'][0])
a,b
# Out:
# (0.9567006376655429, 0.8250310029221779)

# %%
data
# Out:
# Columns:
# 	URI	str
# 	name	str
# 	text	str
# 	word_count	dict
# 	tfidf	dict
#
# Rows: 59071
#
# Data:
# +-------------------------------+---------------------+
# |              URI              |         name        |
# +-------------------------------+---------------------+
# | <http://dbpedia.org/resour... |    Digby Morrell    |
# | <http://dbpedia.org/resour... |    Alfred J. Lewy   |
# | <http://dbpedia.org/resour... |    Harpdog Brown    |
# | <http://dbpedia.org/resour... | Franz Rottensteiner |
# | <http://dbpedia.org/resour... |        G-Enka       |
# | <http://dbpedia.org/resour... |    Sam Henderson    |
# | <http://dbpedia.org/resour... |    Aaron LaCrate    |
# | <http://dbpedia.org/resour... |   Trevor Ferguson   |
# | <http://dbpedia.org/resour... |     Grant Nelson    |
# | <http://dbpedia.org/resour... |     Cathy Caruth    |
# +-------------------------------+---------------------+
# +-------------------------------+-------------------------------+
# ...

# %%
tf_model=graphlab.nearest_neighbors.create(data,features=['tfidf'],label='name',distance='cosine')
# Out:
# Starting brute force nearest neighbors model training.

# %%
wc_model=graphlab.nearest_neighbors.create(data,features=['word_count'],label='name',distance='cosine')
# Out:
# Starting brute force nearest neighbors model training.

# %%
wc_model
# Out:
# Class                          : NearestNeighborsModel
#
# Attributes
# ----------
# Method                         : brute_force
# Number of distance components  : 1
# Number of examples             : 59071
# Number of feature columns      : 1
# Number of unpacked features    : 547979
# Total training time (seconds)  : 4.113

# %%
wc_model.query(elton)
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.00169288  | 6.517ms      |
# | Done         |         | 100         | 215.576ms    |
# +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+-------------------+-------------------+------+
# | query_label |  reference_label  |      distance     | rank |
# +-------------+-------------------+-------------------+------+
# |      0      |     Elton John    | 2.22044604925e-16 |  1   |
# |      0      |   Cliff Richard   |   0.16142415259   |  2   |
# |      0      |   Sandro Petrone  |   0.16822542751   |  3   |
# |      0      |    Rod Stewart    |   0.168327165587  |  4   |
# ...

# %%
elton=data[data['name']=='Elton John']
victoria=data[data['name']=='Victoria Beckham']

# %%
tf_model.query(elton)
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.00169288  | 6.517ms      |
# | Done         |         | 100         | 233.124ms    |
# +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+------------------+--------------------+------+
# | query_label | reference_label  |      distance      | rank |
# +-------------+------------------+--------------------+------+
# |      0      |    Elton John    | -2.22044604925e-16 |  1   |
# |      0      |   Rod Stewart    |   0.717219667893   |  2   |
# |      0      |  George Michael  |   0.747600998969   |  3   |
# |      0      | Sting (musician) |   0.747671954431   |  4   |
# ...

# %%
tf_model.query(victoria)
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.00169288  | 8.522ms      |
# | Done         |         | 100         | 221.09ms     |
# +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+---------------------+-------------------+------+
# | query_label |   reference_label   |      distance     | rank |
# +-------------+---------------------+-------------------+------+
# |      0      |   Victoria Beckham  | 1.11022302463e-16 |  1   |
# |      0      |    David Beckham    |   0.548169610263  |  2   |
# |      0      | Stephen Dow Beckham |   0.784986706828  |  3   |
# |      0      |        Mel B        |   0.809585523409  |  4   |
# ...

# %%
wc_model.query(victoria)
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.00169288  | 5.013ms      |
# | Done         |         | 100         | 223.598ms    |
# +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+--------------------------+--------------------+------+
# | query_label |     reference_label      |      distance      | rank |
# +-------------+--------------------------+--------------------+------+
# |      0      |     Victoria Beckham     | -2.22044604925e-16 |  1   |
# |      0      | Mary Fitzgerald (artist) |   0.207307036115   |  2   |
# |      0      |      Adrienne Corri      |   0.214509782788   |  3   |
# |      0      |     Beverly Jane Fry     |   0.217466468741   |  4   |
# ...
